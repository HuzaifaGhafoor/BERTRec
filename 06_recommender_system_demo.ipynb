# %% [markdown]
# # Part 6: Recommender System Demo and Evaluation

# %% [markdown]
# This notebook demonstrates the complete sentiment-based recommender system in action. Users can input reviews, get sentiment predictions, and receive business recommendations based on sentiment patterns and business similarity.

# %% [markdown]
# ## Importing Dependencies

# %%
import os
import joblib
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from transformers import AutoModel, AutoTokenizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import StandardScaler
from scipy import sparse
import matplotlib.pyplot as plt
import seaborn as sns
import json
import warnings
warnings.filterwarnings('ignore')

# Set style for plots
plt.style.use('seaborn-v0_8')
sns.set_palette('husl')

# %% [markdown]
# ## Core Model and Recommender Definitions

# %%
class RoBERTa_LSTM(nn.Module):
    """RoBERTa encoder followed by an LSTM and classification head."""

    def __init__(self, roberta_model='roberta-base', lstm_hidden=256, num_classes=3):
        super().__init__()
        self.roberta = AutoModel.from_pretrained(roberta_model)
        self.lstm = nn.LSTM(
            input_size=self.roberta.config.hidden_size,
            hidden_size=lstm_hidden,
            batch_first=True,
            bidirectional=True,
        )
        self.norm = nn.LayerNorm(lstm_hidden * 2)
        self.drop = nn.Dropout(0.4)
        self.fc = nn.Linear(lstm_hidden * 2, num_classes)

    def forward(self, input_ids, attention_mask):
        roberta_out = self.roberta(input_ids=input_ids, attention_mask=attention_mask).last_hidden_state
        lstm_out, _ = self.lstm(roberta_out)
        pooled = torch.mean(lstm_out, dim=1)
        normed = self.norm(pooled)
        return self.fc(self.drop(normed))

def predict_sentiment(text, model, tokenizer, device, max_length=512):
    """Predict sentiment label and confidence for the supplied text."""
    model.eval()

    encoding = tokenizer(
        text,
        truncation=True,
        padding='max_length',
        max_length=max_length,
        return_tensors='pt'
    )

    input_ids = encoding['input_ids'].to(device)
    attention_mask = encoding['attention_mask'].to(device)

    with torch.no_grad():
        outputs = model(input_ids, attention_mask)
        probabilities = torch.softmax(outputs, dim=1)
        predicted_class = torch.argmax(probabilities, dim=1).item()
        confidence = probabilities[0][predicted_class].item()

    sentiment_map = {0: 'negative', 1: 'neutral', 2: 'positive'}
    return sentiment_map[predicted_class], confidence

class SentimentBasedRecommender:
    def __init__(
        self,
        business_df,
        sentiment_profile_df,
        category_features,
        category_vectorizer,
        sentiment_model,
        tokenizer,
        device,
        merged_reviews_df=None,
    ):
        self.business_df = business_df
        self.sentiment_profile_df = sentiment_profile_df
        self.category_features = category_features.tocsr()
        self.category_vectorizer = category_vectorizer
        self.sentiment_model = sentiment_model
        self.tokenizer = tokenizer
        self.device = device
        self.merged_reviews_df = merged_reviews_df

        self.business_features_df = business_df.merge(sentiment_profile_df, on='business_id', how='left')
        fill_defaults = {
            'negative_ratio': 0.0,
            'neutral_ratio': 0.0,
            'positive_ratio': 0.0,
            'total_reviews': 0.0,
        }
        self.business_features_df = self.business_features_df.fillna(fill_defaults)
        if 'review_count' not in self.business_features_df.columns:
            self.business_features_df['review_count'] = 0
        self.business_features_df['review_count'] = self.business_features_df['review_count'].fillna(0)
        self.business_features_df['city'] = self.business_features_df['city'].fillna('')
        self.business_features_df['state'] = self.business_features_df['state'].fillna('')
        self.business_features_df = self.business_features_df.reset_index(drop=True)
        self.business_features_df['city_state'] = (
            self.business_features_df['city'].astype(str).str.lower().str.strip() + ' ' +
            self.business_features_df['state'].astype(str).str.lower().str.strip()
        ).str.strip()

        self.business_features_df['log_total_reviews'] = np.log1p(
            self.business_features_df['total_reviews'].clip(lower=0)
        )
        max_log = float(self.business_features_df['log_total_reviews'].max() or 1.0)
        self.business_features_df['log_total_reviews_norm'] = self.business_features_df['log_total_reviews'] / max_log

        self.numerical_columns = ['stars', 'review_count', 'negative_ratio', 'neutral_ratio', 'positive_ratio', 'total_reviews']
        self._prepare_feature_matrix()

    def _prepare_feature_matrix(self):
        numerical_data = self.business_features_df[self.numerical_columns].fillna(0).to_numpy(dtype=float)
        self.scaler = StandardScaler()
        numerical_scaled = self.scaler.fit_transform(numerical_data)
        numerical_sparse = sparse.csr_matrix(numerical_scaled)
        self.feature_matrix = sparse.hstack([numerical_sparse, self.category_features]).tocsr()

    def predict_user_sentiment(self, user_review):
        sentiment_label, confidence = predict_sentiment(
            user_review,
            self.sentiment_model,
            self.tokenizer,
            self.device,
        )
        return sentiment_label, confidence

    def find_similar_businesses(self, business_id, top_k=10):
        matches = self.business_features_df[self.business_features_df['business_id'] == business_id]
        if matches.empty:
            return pd.DataFrame(columns=self.business_features_df.columns)

        idx = matches.index[0]
        similarities = cosine_similarity(self.feature_matrix[idx], self.feature_matrix).ravel()
        top_indices = np.argsort(similarities)[::-1]
        top_indices = [i for i in top_indices if i != idx][:top_k]

        if not top_indices:
            return pd.DataFrame(columns=self.business_features_df.columns)

        results = self.business_features_df.iloc[top_indices].copy()
        results['similarity_score'] = similarities[top_indices]
        return results

    def recommend_from_review(
        self,
        user_review,
        user_location=None,
        category_preference=None,
        top_k=10,
    ):
        sentiment_label, confidence = self.predict_user_sentiment(user_review)

        candidate_mask = self._filter_by_sentiment(sentiment_label)
        candidates = self.business_features_df.loc[candidate_mask].copy()

        if user_location:
            candidates = self._apply_location_filter(candidates, user_location)

        if category_preference:
            category_mask = candidates['categories'].fillna('').str.contains(category_preference, case=False, na=False)
            candidates = candidates.loc[category_mask]

        if candidates.empty:
            return sentiment_label, confidence, candidates

        scored = self._score_candidates(
            candidates,
            sentiment_label=sentiment_label,
            query_text=category_preference or user_review,
            explicit_category=category_preference,
        )

        if top_k:
            scored = scored.nlargest(top_k, 'composite_score').reset_index(drop=True)
        else:
            scored = scored.sort_values('composite_score', ascending=False).reset_index(drop=True)

        scored.insert(0, 'rank', np.arange(1, len(scored) + 1))
        return sentiment_label, confidence, scored

    def _filter_by_sentiment(self, sentiment_label):
        thresholds = {
            'positive': {'positive_ratio': 0.55, 'min_reviews': 5},
            'neutral': {'positive_ratio': 0.45, 'min_reviews': 3},
            'negative': {'positive_ratio': 0.65, 'min_reviews': 8},
        }
        config = thresholds.get(sentiment_label, thresholds['neutral'])

        mask = (
            (self.business_features_df['total_reviews'] >= config['min_reviews']) &
            (self.business_features_df['positive_ratio'] >= config['positive_ratio'])
        )
        return mask

    def _apply_location_filter(self, df, location_query):
        tokens = [token.strip().lower() for token in str(location_query).split(',') if token.strip()]
        if not tokens:
            tokens = [str(location_query).strip().lower()]

        mask = np.zeros(len(df), dtype=bool)
        for token in tokens:
            if token:
                mask |= df['city_state'].str.contains(token, na=False)
        filtered = df[mask]
        return filtered if not filtered.empty else df

    def _score_candidates(self, df, *, sentiment_label, query_text, explicit_category):
        query_vec = self.category_vectorizer.transform([query_text])
        candidate_indices = np.asarray(df.index)
        candidate_features = self.category_features[candidate_indices]
        category_scores = cosine_similarity(query_vec, candidate_features).ravel()
        category_scores = np.nan_to_num(category_scores, nan=0.0, posinf=0.0, neginf=0.0)
        if explicit_category:
            category_scores = np.maximum(category_scores, 0.3)

        sentiment_targets = {'positive': 0.75, 'neutral': 0.5, 'negative': 0.8}
        target = sentiment_targets.get(sentiment_label, 0.5)
        sentiment_alignment = 1 - np.abs(df['positive_ratio'] - target)
        sentiment_alignment = sentiment_alignment.clip(lower=0)

        composite_score = (
            0.25 * df['positive_ratio'] +
            0.2 * (df['stars'].fillna(0) / 5.0) +
            0.2 * sentiment_alignment +
            0.15 * df['log_total_reviews_norm'] +
            0.1 * (1 - df['negative_ratio']) +
            0.1 * category_scores
        )

        scored = df.copy()
        scored['category_similarity'] = category_scores
        scored['sentiment_alignment'] = sentiment_alignment
        scored['composite_score'] = composite_score
        return scored

    def export_assets(self):
        return {
            'business_features_df': self.business_features_df,
            'sentiment_profile_df': self.sentiment_profile_df,
            'category_features': self.category_features,
            'category_vectorizer': self.category_vectorizer,
            'feature_matrix': self.feature_matrix,
            'numerical_columns': self.numerical_columns,
            'scaler': self.scaler,
            'merged_reviews_df': self.merged_reviews_df,
        }

# %% [markdown]
# ## Load Pre-trained Components

# %%
ASSET_PATH = 'artifacts/recommender_assets.joblib'
MODEL_PATH = 'best_model.pt'

if not os.path.exists(ASSET_PATH):
    raise FileNotFoundError(
        f"Missing recommender assets at {ASSET_PATH}. Run notebook 05 to generate them."
    )

assets = joblib.load(ASSET_PATH)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
sentiment_model = RoBERTa_LSTM()
sentiment_model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
sentiment_model = sentiment_model.to(device)
sentiment_model.eval()

tokenizer = AutoTokenizer.from_pretrained('roberta-base')

category_features = assets['category_features']
category_vectorizer = assets['category_vectorizer']
base_business_df = assets['business_features_df']
sentiment_profile_df = assets['sentiment_profile_df']
merged_df = assets.get('merged_reviews_df')

recommender = SentimentBasedRecommender(
    business_df=base_business_df,
    sentiment_profile_df=sentiment_profile_df,
    category_features=category_features,
    category_vectorizer=category_vectorizer,
    sentiment_model=sentiment_model,
    tokenizer=tokenizer,
    device=device,
    merged_reviews_df=merged_df,
)

business_df = recommender.business_features_df
if merged_df is None:
    merged_df = recommender.merged_reviews_df

print('Recommender loaded successfully!')
print(f"Businesses available: {len(business_df):,}")
if merged_df is not None:
    print(f"Reviews available: {len(merged_df):,}")

# %% [markdown]
# ## Enhanced Recommendation Function

# %%
def recommend_businesses_from_review(user_review, user_location=None, category_preference=None, top_k=5):
    """Run the end-to-end recommendation pipeline for a user-provided review."""
    print('=' * 60)
    print('SENTIMENT-BASED BUSINESS RECOMMENDER SYSTEM')
    print('=' * 60)

    truncated_review = user_review[:120] + ('...' if len(user_review) > 120 else '')
    print(f"
📝 User Review: '{truncated_review}'")

    sentiment_label, confidence, results = recommender.recommend_from_review(
        user_review=user_review,
        user_location=user_location,
        category_preference=category_preference,
        top_k=top_k,
    )

    print(f"
🎯 Predicted Sentiment: {sentiment_label.upper()} (Confidence: {confidence:.3f})")
    if user_location:
        print(f"📍 Location Preference: {user_location}")
    if category_preference:
        print(f"🏷️ Category Preference: {category_preference}")

    if results.empty:
        print('
❌ No businesses found matching your criteria. Try broader filters.')
        return {'sentiment': sentiment_label, 'confidence': confidence, 'recommendations': results}

    print(f"
🎯 Top {len(results)} Recommendations:")
    print('=' * 60)

    for row in results.itertuples(index=False):
        print(f"
{row.rank}. {row.name}")
        print(f"   📍 {row.city}, {row.state}")
        print(f"   ⭐ {row.stars:.1f}/5.0 stars")
        print(f"   😊 {row.positive_ratio:.1%} positive reviews ({int(row.total_reviews)} total)")
        if hasattr(row, 'category_similarity'):
            print(f"   🧭 Category match: {row.category_similarity:.2f}")
        if hasattr(row, 'sentiment_alignment'):
            print(f"   💬 Sentiment alignment: {row.sentiment_alignment:.2f}")
        category_text = str(row.categories)
        print(f"   🏷️ {category_text[:80]}{'...' if len(category_text) > 80 else ''}")
        print(f"   📊 Score: {row.composite_score:.3f}")

    return {'sentiment': sentiment_label, 'confidence': confidence, 'recommendations': results}

# %% [markdown]
# ## Demo: Restaurant Recommendation

# %%
# Example 1: Positive review about a restaurant
positive_review = """
Amazing dining experience! The food was absolutely delicious, 
service was outstanding, and the atmosphere was perfect for a date night. 
The pasta was cooked to perfection and the dessert was heavenly. 
Will definitely come back!
"""

recommendations_1 = recommend_businesses_from_review(
    user_review=positive_review,
    user_location="Las Vegas",
    category_preference="Restaurants",
    top_k=5
)

# %% [markdown]
# ## Demo: Hotel Recommendation

# %%
# Example 2: Negative review about a hotel
negative_review = """
Terrible experience at this hotel. The room was dirty, 
staff was rude, and the facilities were outdated. 
The bed was uncomfortable and there was noise all night. 
Would not recommend to anyone.
"""

recommendations_2 = recommend_businesses_from_review(
    user_review=negative_review,
    user_location="Phoenix",
    category_preference="Hotels",
    top_k=3
)

# %% [markdown]
# ## Demo: General Business Recommendation

# %%
# Example 3: Neutral review about shopping
neutral_review = """
The store was okay, nothing special but not bad either. 
They had what I needed and the prices were reasonable. 
Staff was helpful when I asked questions.
"""

recommendations_3 = recommend_businesses_from_review(
    user_review=neutral_review,
    user_location="Toronto",
    category_preference="Shopping",
    top_k=4
)

# %% [markdown]
# ## Visualization: Sentiment Distribution Analysis

# %%
# Analyze sentiment distribution across different business categories
def plot_sentiment_analysis():
    fig, axes = plt.subplots(2, 2, figsize=(15, 12))
    
    # 1. Overall sentiment distribution
    sentiment_counts = merged_df['sentiment'].value_counts()
    axes[0, 0].pie(sentiment_counts.values, labels=sentiment_counts.index, autopct='%1.1f%%', startangle=90)
    axes[0, 0].set_title('Overall Sentiment Distribution', fontsize=14, fontweight='bold')
    
    # 2. Business rating vs sentiment
    sentiment_by_rating = merged_df.groupby(['stars_business', 'sentiment']).size().unstack(fill_value=0)
    sentiment_by_rating_pct = sentiment_by_rating.div(sentiment_by_rating.sum(axis=1), axis=0) * 100
    sentiment_by_rating_pct.plot(kind='bar', stacked=True, ax=axes[0, 1], 
                                 color=['#ff6b6b', '#ffd93d', '#6bcf7f'])
    axes[0, 1].set_title('Sentiment Distribution by Business Rating', fontsize=14, fontweight='bold')
    axes[0, 1].set_xlabel('Business Stars')
    axes[0, 1].set_ylabel('Percentage')
    axes[0, 1].legend(title='Sentiment')
    axes[0, 1].tick_params(axis='x', rotation=0)
    
    # 3. Top categories by positive sentiment ratio
    category_sentiment = []
    for _, business in business_df.head(100).iterrows():  # Sample for performance
        if pd.notna(business['categories']):
            categories = [cat.strip() for cat in business['categories'].split(',')]
            for category in categories[:3]:  # Top 3 categories per business
                business_reviews = merged_df[merged_df['business_id'] == business['business_id']]
                if len(business_reviews) > 0:
                    positive_ratio = (business_reviews['sentiment'] == 'positive').mean()
                    category_sentiment.append({'category': category, 'positive_ratio': positive_ratio})
    
    if category_sentiment:
        category_df = pd.DataFrame(category_sentiment)
        top_categories = category_df.groupby('category')['positive_ratio'].mean().nlargest(10)
        top_categories.plot(kind='barh', ax=axes[1, 0], color='skyblue')
        axes[1, 0].set_title('Top 10 Categories by Positive Sentiment Ratio', fontsize=14, fontweight='bold')
        axes[1, 0].set_xlabel('Average Positive Sentiment Ratio')
    
    # 4. Business sentiment profile distribution
    axes[1, 1].hist(sentiment_profile_df['positive_ratio'], bins=30, alpha=0.7, color='green', label='Positive')
    axes[1, 1].hist(sentiment_profile_df['negative_ratio'], bins=30, alpha=0.7, color='red', label='Negative')
    axes[1, 1].set_title('Distribution of Business Sentiment Ratios', fontsize=14, fontweight='bold')
    axes[1, 1].set_xlabel('Sentiment Ratio')
    axes[1, 1].set_ylabel('Number of Businesses')
    axes[1, 1].legend()
    
    plt.tight_layout()
    plt.show()

plot_sentiment_analysis()

# %% [markdown]
# ## System Performance Evaluation

# %%
# Evaluate recommendation system performance
def evaluate_recommendation_system():
    print("=" * 60)
    print("RECOMMENDATION SYSTEM EVALUATION")
    print("=" * 60)
    
    # 1. Dataset Statistics
    print(f"\n📊 Dataset Statistics:")
    print(f"   • Total Businesses: {len(business_df):,}")
    print(f"   • Total Reviews: {len(merged_df):,}")
    print(f"   • Businesses with Sentiment Profiles: {len(sentiment_profile_df):,}")
    print(f"   • Average Reviews per Business: {merged_df.groupby('business_id').size().mean():.1f}")
    
    # 2. Sentiment Model Performance (from previous notebook)
    print(f"\n🎯 Sentiment Model Performance:")
    print(f"   • Model: RoBERTa-LSTM")
    print(f"   • Test Accuracy: 86.0%")
    print(f"   • F1-Score: 86.0%")
    print(f"   • Classes: Negative (0), Neutral (1), Positive (2)")
    
    # 3. Business Coverage Analysis
    businesses_with_reviews = sentiment_profile_df[sentiment_profile_df['total_reviews'] > 0]
    high_confidence_businesses = businesses_with_reviews[businesses_with_reviews['total_reviews'] >= 10]
    
    print(f"\n🏢 Business Coverage:")
    print(f"   • Businesses with Reviews: {len(businesses_with_reviews):,} ({len(businesses_with_reviews)/len(business_df)*100:.1f}%)")
    print(f"   • High Confidence Businesses (≥10 reviews): {len(high_confidence_businesses):,}")
    print(f"   • Average Positive Sentiment Ratio: {businesses_with_reviews['positive_ratio'].mean():.3f}")
    
    # 4. Category Distribution
    category_counts = {}
    for categories_str in business_df['categories'].dropna():
        for category in categories_str.split(','):
            category = category.strip()
            category_counts[category] = category_counts.get(category, 0) + 1
    
    top_categories = sorted(category_counts.items(), key=lambda x: x[1], reverse=True)[:10]
    print(f"\n🏷️ Top Business Categories:")
    for i, (category, count) in enumerate(top_categories, 1):
        print(f"   {i:2d}. {category}: {count:,} businesses")
    
    # 5. Recommendation Quality Metrics
    print(f"\n⚡ System Capabilities:")
    print(f"   • Real-time sentiment analysis of user reviews")
    print(f"   • Content-based filtering using business features")
    print(f"   • Location and category filtering")
    print(f"   • Composite scoring with multiple factors")
    print(f"   • Scalable to {len(business_df):,}+ businesses")

evaluate_recommendation_system()

# %% [markdown]
# ## Interactive Recommendation Interface

# %%
def interactive_recommendation():
    """
    Interactive function for users to get recommendations
    """
    print("\n" + "=" * 60)
    print("🎯 INTERACTIVE BUSINESS RECOMMENDER")
    print("=" * 60)
    print("\nShare your experience and get personalized recommendations!")
    
    # Sample inputs for demonstration
    sample_reviews = [
        "The coffee was amazing and the barista was so friendly! Great atmosphere for working.",
        "Food was cold and service was terrible. Very disappointed with this place.",
        "Decent place, nothing extraordinary but good value for money.",
        "Outstanding service! The staff went above and beyond to make our experience special.",
        "The gym equipment is outdated and the facility needs better maintenance."
    ]
    
    sample_locations = ["Las Vegas", "Phoenix", "Toronto", "Charlotte", "Pittsburgh"]
    sample_categories = ["Coffee & Tea", "Restaurants", "Shopping", "Hotels & Travel", "Active Life"]
    
    print("\n📝 Sample Reviews to Try:")
    for i, review in enumerate(sample_reviews, 1):
        print(f"   {i}. {review}")
    
    print("\n📍 Sample Locations: ", ", ".join(sample_locations))
    print("🏷️ Sample Categories: ", ", ".join(sample_categories))
    
    # For demonstration, use the first sample
    print("\n" + "-" * 60)
    print("DEMO: Using Sample Review #1")
    print("-" * 60)
    
    recommendations = recommend_businesses_from_review(
        user_review=sample_reviews[0],
        user_location=sample_locations[0],
        category_preference=sample_categories[0],
        top_k=3
    )
    
    return recommendations

# Run interactive demo
demo_recommendations = interactive_recommendation()

# %% [markdown]
# ## Summary and Conclusions

# %%
print("=" * 70)
print("🎉 SENTIMENT-BASED RECOMMENDER SYSTEM - SUMMARY")
print("=" * 70)

print("\n🔬 TECHNICAL ACHIEVEMENTS:")
print("   ✅ Integrated BERT-LSTM sentiment analysis (86% F1-score)")
print("   ✅ Built content-based recommender system")
print("   ✅ Combined sentiment patterns with business features")
print("   ✅ Implemented location and category filtering")
print("   ✅ Created composite scoring algorithm")

print("\n🎯 SYSTEM CAPABILITIES:")
print("   • Real-time sentiment analysis of user reviews")
print("   • Personalized business recommendations")
print("   • Multi-factor recommendation scoring")
print("   • Scalable to large business datasets")
print("   • Interactive user interface")

print("\n📊 DATASET COVERAGE:")
print(f"   • {len(business_df):,} businesses analyzed")
print(f"   • {len(merged_df):,} reviews processed")
print(f"   • {len(sentiment_profile_df):,} sentiment profiles created")
print(f"   • Multiple cities and business categories")

print("\n🚀 FUTURE ENHANCEMENTS:")
print("   • Collaborative filtering integration")
print("   • Deep learning embeddings for businesses")
print("   • Real-time review stream processing")
print("   • Advanced user preference learning")
print("   • Mobile app deployment")

print("\n" + "=" * 70)
print("✨ System successfully combines NLP and recommendation algorithms!")
print("=" * 70)
