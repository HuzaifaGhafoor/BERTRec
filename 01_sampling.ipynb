# %% [markdown]
# # Part 1: Data Sampling

# %% [markdown]
# The Yelp Reviews dataset is large (~9GB) and is in JSON format, which can lead to high memory usage when processed directly. To make the dataset more manageable, we will focus on the `reviews` subset and reduce it to approximately 1.5 million reviews. This reduction allows us to retain a good portion of the data while keeping memory and computation demands within limits.
#
# Fine-tuning BERT on medium-sized datasets such as this can lead to significant performance improvements. Reducing the dataset ensures it fits within system constraints, and 1.5 million reviews provides a sufficient sample size for building a content-based recommender system capable of delivering meaningful insights.

# %% [markdown]
# ## Importing Dependencies

# %% [markdown]
# Since the `reviews` dataset is large, loading it directly using pandas can result in memory exhaustion, as pandas loads the entire dataset into memory at once. To handle the dataset more efficiently, we will use **Dask**, a parallel computing library that supports lazy evaluation. Dask is designed to manage larger datasets by loading data as needed, thus minimizing memory usage.

# %%
import pandas as pd
import dask.dataframe as dd

# %% [markdown]
# ## Loading Dataset

# %% [markdown]
# We use gdown, which is a Python CLI-based tool to download files and folders from Google Drive.

# %%
# !pip install -q gdown                                                             # Install gdown in quiet mode, suppressing logs

# !gdown --folder 1j8RLxZYJfonGETCwlw1fUl1zaafAqtse -O /content/YelpDataset         # Download the folder with the id and save the
                                                                                  # results to /content/YelpDataset
# Out:
# Retrieving folder contents
# Processing file 1PgywSzvyZ-LodDZReL9cwk3EoEfSBtAZ Dataset_User_Agreement.pdf
# Processing file 167HeuRH581eFsso0PtmUyWoT1pHp4kUI yelp_academic_dataset_business.json
# Processing file 16i_3i2jwOfJ0MStpq3uBnNPoFjkLRrt5 yelp_academic_dataset_checkin.json
# Processing file 1ADMBGRjbkEfkRbqLCVisfs63uGh9c91o yelp_academic_dataset_review.json
# Processing file 1g6WBceed7ntCNgAoV5hjnkulqkVBHDIJ yelp_academic_dataset_tip.json
# Processing file 1tmKspFRt8vs3v0AFz-KcbEY9p1wrFSUP yelp_academic_dataset_user.json
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1PgywSzvyZ-LodDZReL9cwk3EoEfSBtAZ
# To: /content/YelpDataset/Dataset_User_Agreement.pdf
# 100% 80.4k/80.4k [00:00<00:00, 76.9MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=167HeuRH581eFsso0PtmUyWoT1pHp4kUI
# From (redirected): https://drive.google.com/uc?id=167HeuRH581eFsso0PtmUyWoT1pHp4kUI&confirm=t&uuid=4ada7e4d-97b9-4032-aef4-e79da37b8c34
# To: /content/YelpDataset/yelp_academic_dataset_business.json
# 100% 119M/119M [00:02<00:00, 47.5MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=16i_3i2jwOfJ0MStpq3uBnNPoFjkLRrt5
# From (redirected): https://drive.google.com/uc?id=16i_3i2jwOfJ0MStpq3uBnNPoFjkLRrt5&confirm=t&uuid=ccdb5157-5596-4cf7-bbdb-67385ac9e1cb
# To: /content/YelpDataset/yelp_academic_dataset_checkin.json
# 100% 287M/287M [00:03<00:00, 80.0MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1ADMBGRjbkEfkRbqLCVisfs63uGh9c91o
# From (redirected): https://drive.google.com/uc?id=1ADMBGRjbkEfkRbqLCVisfs63uGh9c91o&confirm=t&uuid=23261319-c8f6-4bf8-ae91-c132f72f1864
# To: /content/YelpDataset/yelp_academic_dataset_review.json
# 100% 5.34G/5.34G [01:33<00:00, 57.1MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1g6WBceed7ntCNgAoV5hjnkulqkVBHDIJ
# From (redirected): https://drive.google.com/uc?id=1g6WBceed7ntCNgAoV5hjnkulqkVBHDIJ&confirm=t&uuid=1c5d44dd-75cb-458e-a2b7-ef964c09ff06
# To: /content/YelpDataset/yelp_academic_dataset_tip.json
# 100% 181M/181M [00:02<00:00, 85.3MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1tmKspFRt8vs3v0AFz-KcbEY9p1wrFSUP
# From (redirected): https://drive.google.com/uc?id=1tmKspFRt8vs3v0AFz-KcbEY9p1wrFSUP&confirm=t&uuid=3e5338fa-51c6-4221-a4ff-0fb1632f645d
# To: /content/YelpDataset/yelp_academic_dataset_user.json
# 100% 3.36G/3.36G [00:58<00:00, 57.8MB/s]
# Download completed

# %% [markdown]
# ## Chunking Dataset

# %% [markdown]
# To reduce memory overhead, we will define a `chunk_size` variable to load the dataset in smaller parts. The dataset will be loaded in **parquet** format, which is more compact and efficient than JSON. The parquet format helps reduce the overall size of the dataset while maintaining structure.

# %%
chunk_size = 10_000
parquet_file = '/content/Dataset/yelp_reviews.parquet'

# The 'lines=True' argument ensures that each line in the file is treated as a separate JSON object

chunks = pd.read_json('/content/YelpDataset/yelp_academic_dataset_review.json', lines=True, chunksize=chunk_size)

# %% [markdown]
# We will convert the dataset to parquet format by appending the data in chunks. This approach helps keep memory usage low by processing the file incrementally. For that, we need to download the `fastparquet` engine. We also create the folder to save the parquet.

# %%
# !pip install -q fastparquet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 20.7 MB/s eta 0:00:00

# %%
# !mkdir /content/Dataset

# %%
for i, chunk in enumerate(chunks):
    chunk.to_parquet(parquet_file, engine='fastparquet', index=False, compression='snappy', append=(i > 0))
    print(f"Chunk {i} appended.")
# Out:
# Chunk 0 appended.
# Chunk 1 appended.
# Chunk 2 appended.
# Chunk 3 appended.
# Chunk 4 appended.
# Chunk 5 appended.
# Chunk 6 appended.
# Chunk 7 appended.
# Chunk 8 appended.
# Chunk 9 appended.
# Chunk 10 appended.
# Chunk 11 appended.
# Chunk 12 appended.
# Chunk 13 appended.
# Chunk 14 appended.
# Chunk 15 appended.
# Chunk 16 appended.
# Chunk 17 appended.
# Chunk 18 appended.
# Chunk 19 appended.
# Chunk 20 appended.
# Chunk 21 appended.
# Chunk 22 appended.
# Chunk 23 appended.
# Chunk 24 appended.
# Chunk 25 appended.
# Chunk 26 appended.
# Chunk 27 appended.
# Chunk 28 appended.
# Chunk 29 appended.
# Chunk 30 appended.
# Chunk 31 appended.
# Chunk 32 appended.
# Chunk 33 appended.
# Chunk 34 appended.
# Chunk 35 appended.
# Chunk 36 appended.
# Chunk 37 appended.
# Chunk 38 appended.
# Chunk 39 appended.
# Chunk 40 appended.
# Chunk 41 appended.
# Chunk 42 appended.
# Chunk 43 appended.
# Chunk 44 appended.
# Chunk 45 appended.
# Chunk 46 appended.
# Chunk 47 appended.
# Chunk 48 appended.
# Chunk 49 appended.
# Chunk 50 appended.
# Chunk 51 appended.
# Chunk 52 appended.
# Chunk 53 appended.
# Chunk 54 appended.
# Chunk 55 appended.
# Chunk 56 appended.
# Chunk 57 appended.
# Chunk 58 appended.
# Chunk 59 appended.
# Chunk 60 appended.
# Chunk 61 appended.
# Chunk 62 appended.
# Chunk 63 appended.
# Chunk 64 appended.
# Chunk 65 appended.
# Chunk 66 appended.
# Chunk 67 appended.
# Chunk 68 appended.
# Chunk 69 appended.
# Chunk 70 appended.
# Chunk 71 appended.
# Chunk 72 appended.
# Chunk 73 appended.
# Chunk 74 appended.
# Chunk 75 appended.
# Chunk 76 appended.
# Chunk 77 appended.
# Chunk 78 appended.
# Chunk 79 appended.
# Chunk 80 appended.
# Chunk 81 appended.
# Chunk 82 appended.
# Chunk 83 appended.
# Chunk 84 appended.
# Chunk 85 appended.
# Chunk 86 appended.
# Chunk 87 appended.
# Chunk 88 appended.
# Chunk 89 appended.
# Chunk 90 appended.
# Chunk 91 appended.
# Chunk 92 appended.
# Chunk 93 appended.
# Chunk 94 appended.
# Chunk 95 appended.
# Chunk 96 appended.
# Chunk 97 appended.
# Chunk 98 appended.
# Chunk 99 appended.
# Chunk 100 appended.
# Chunk 101 appended.
# Chunk 102 appended.
# Chunk 103 appended.
# Chunk 104 appended.
# Chunk 105 appended.
# Chunk 106 appended.
# Chunk 107 appended.
# Chunk 108 appended.
# Chunk 109 appended.
# Chunk 110 appended.
# Chunk 111 appended.
# Chunk 112 appended.
# Chunk 113 appended.
# Chunk 114 appended.
# Chunk 115 appended.
# Chunk 116 appended.
# Chunk 117 appended.
# Chunk 118 appended.
# Chunk 119 appended.
# Chunk 120 appended.
# Chunk 121 appended.
# Chunk 122 appended.
# Chunk 123 appended.
# Chunk 124 appended.
# Chunk 125 appended.
# Chunk 126 appended.
# Chunk 127 appended.
# Chunk 128 appended.
# Chunk 129 appended.
# Chunk 130 appended.
# Chunk 131 appended.
# Chunk 132 appended.
# Chunk 133 appended.
# Chunk 134 appended.
# Chunk 135 appended.
# Chunk 136 appended.
# Chunk 137 appended.
# Chunk 138 appended.
# Chunk 139 appended.
# Chunk 140 appended.
# Chunk 141 appended.
# Chunk 142 appended.
# Chunk 143 appended.
# Chunk 144 appended.
# Chunk 145 appended.
# Chunk 146 appended.
# Chunk 147 appended.
# Chunk 148 appended.
# Chunk 149 appended.
# Chunk 150 appended.
# Chunk 151 appended.
# Chunk 152 appended.
# Chunk 153 appended.
# Chunk 154 appended.
# Chunk 155 appended.
# Chunk 156 appended.
# Chunk 157 appended.
# Chunk 158 appended.
# Chunk 159 appended.
# Chunk 160 appended.
# Chunk 161 appended.
# Chunk 162 appended.
# Chunk 163 appended.
# Chunk 164 appended.
# Chunk 165 appended.
# Chunk 166 appended.
# Chunk 167 appended.
# Chunk 168 appended.
# Chunk 169 appended.
# Chunk 170 appended.
# Chunk 171 appended.
# Chunk 172 appended.
# Chunk 173 appended.
# Chunk 174 appended.
# Chunk 175 appended.
# Chunk 176 appended.
# Chunk 177 appended.
# Chunk 178 appended.
# Chunk 179 appended.
# Chunk 180 appended.
# Chunk 181 appended.
# Chunk 182 appended.
# Chunk 183 appended.
# Chunk 184 appended.
# Chunk 185 appended.
# Chunk 186 appended.
# Chunk 187 appended.
# Chunk 188 appended.
# Chunk 189 appended.
# Chunk 190 appended.
# Chunk 191 appended.
# Chunk 192 appended.
# Chunk 193 appended.
# Chunk 194 appended.
# Chunk 195 appended.
# Chunk 196 appended.
# Chunk 197 appended.
# Chunk 198 appended.
# Chunk 199 appended.
# Chunk 200 appended.
# Chunk 201 appended.
# Chunk 202 appended.
# Chunk 203 appended.
# Chunk 204 appended.
# Chunk 205 appended.
# Chunk 206 appended.
# Chunk 207 appended.
# Chunk 208 appended.
# Chunk 209 appended.
# Chunk 210 appended.
# Chunk 211 appended.
# Chunk 212 appended.
# Chunk 213 appended.
# Chunk 214 appended.
# Chunk 215 appended.
# Chunk 216 appended.
# Chunk 217 appended.
# Chunk 218 appended.
# Chunk 219 appended.
# Chunk 220 appended.
# Chunk 221 appended.
# Chunk 222 appended.
# Chunk 223 appended.
# Chunk 224 appended.
# Chunk 225 appended.
# Chunk 226 appended.
# Chunk 227 appended.
# Chunk 228 appended.
# Chunk 229 appended.
# Chunk 230 appended.
# Chunk 231 appended.
# Chunk 232 appended.
# Chunk 233 appended.
# Chunk 234 appended.
# Chunk 235 appended.
# Chunk 236 appended.
# Chunk 237 appended.
# Chunk 238 appended.
# Chunk 239 appended.
# Chunk 240 appended.
# Chunk 241 appended.
# Chunk 242 appended.
# Chunk 243 appended.
# Chunk 244 appended.
# Chunk 245 appended.
# Chunk 246 appended.
# Chunk 247 appended.
# Chunk 248 appended.
# Chunk 249 appended.
# Chunk 250 appended.
# Chunk 251 appended.
# Chunk 252 appended.
# Chunk 253 appended.
# Chunk 254 appended.
# Chunk 255 appended.
# Chunk 256 appended.
# Chunk 257 appended.
# Chunk 258 appended.
# Chunk 259 appended.
# Chunk 260 appended.
# Chunk 261 appended.
# Chunk 262 appended.
# Chunk 263 appended.
# Chunk 264 appended.
# Chunk 265 appended.
# Chunk 266 appended.
# Chunk 267 appended.
# Chunk 268 appended.
# Chunk 269 appended.
# Chunk 270 appended.
# Chunk 271 appended.
# Chunk 272 appended.
# Chunk 273 appended.
# Chunk 274 appended.
# Chunk 275 appended.
# Chunk 276 appended.
# Chunk 277 appended.
# Chunk 278 appended.
# Chunk 279 appended.
# Chunk 280 appended.
# Chunk 281 appended.
# Chunk 282 appended.
# Chunk 283 appended.
# Chunk 284 appended.
# Chunk 285 appended.
# Chunk 286 appended.
# Chunk 287 appended.
# Chunk 288 appended.
# Chunk 289 appended.
# Chunk 290 appended.
# Chunk 291 appended.
# Chunk 292 appended.
# Chunk 293 appended.
# Chunk 294 appended.
# Chunk 295 appended.
# Chunk 296 appended.
# Chunk 297 appended.
# Chunk 298 appended.
# Chunk 299 appended.
# Chunk 300 appended.
# Chunk 301 appended.
# Chunk 302 appended.
# Chunk 303 appended.
# Chunk 304 appended.
# Chunk 305 appended.
# Chunk 306 appended.
# Chunk 307 appended.
# Chunk 308 appended.
# Chunk 309 appended.
# Chunk 310 appended.
# Chunk 311 appended.
# Chunk 312 appended.
# Chunk 313 appended.
# Chunk 314 appended.
# Chunk 315 appended.
# Chunk 316 appended.
# Chunk 317 appended.
# Chunk 318 appended.
# Chunk 319 appended.
# Chunk 320 appended.
# Chunk 321 appended.
# Chunk 322 appended.
# Chunk 323 appended.
# Chunk 324 appended.
# Chunk 325 appended.
# Chunk 326 appended.
# Chunk 327 appended.
# Chunk 328 appended.
# Chunk 329 appended.
# Chunk 330 appended.
# Chunk 331 appended.
# Chunk 332 appended.
# Chunk 333 appended.
# Chunk 334 appended.
# Chunk 335 appended.
# Chunk 336 appended.
# Chunk 337 appended.
# Chunk 338 appended.
# Chunk 339 appended.
# Chunk 340 appended.
# Chunk 341 appended.
# Chunk 342 appended.
# Chunk 343 appended.
# Chunk 344 appended.
# Chunk 345 appended.
# Chunk 346 appended.
# Chunk 347 appended.
# Chunk 348 appended.
# Chunk 349 appended.
# Chunk 350 appended.
# Chunk 351 appended.
# Chunk 352 appended.
# Chunk 353 appended.
# Chunk 354 appended.
# Chunk 355 appended.
# Chunk 356 appended.
# Chunk 357 appended.
# Chunk 358 appended.
# Chunk 359 appended.
# Chunk 360 appended.
# Chunk 361 appended.
# Chunk 362 appended.
# Chunk 363 appended.
# Chunk 364 appended.
# Chunk 365 appended.
# Chunk 366 appended.
# Chunk 367 appended.
# Chunk 368 appended.
# Chunk 369 appended.
# Chunk 370 appended.
# Chunk 371 appended.
# Chunk 372 appended.
# Chunk 373 appended.
# Chunk 374 appended.
# Chunk 375 appended.
# Chunk 376 appended.
# Chunk 377 appended.
# Chunk 378 appended.
# Chunk 379 appended.
# Chunk 380 appended.
# Chunk 381 appended.
# Chunk 382 appended.
# Chunk 383 appended.
# Chunk 384 appended.
# Chunk 385 appended.
# Chunk 386 appended.
# Chunk 387 appended.
# Chunk 388 appended.
# Chunk 389 appended.
# Chunk 390 appended.
# Chunk 391 appended.
# Chunk 392 appended.
# Chunk 393 appended.
# Chunk 394 appended.
# Chunk 395 appended.
# Chunk 396 appended.
# Chunk 397 appended.
# Chunk 398 appended.
# Chunk 399 appended.
# Chunk 400 appended.
# Chunk 401 appended.
# Chunk 402 appended.
# Chunk 403 appended.
# Chunk 404 appended.
# Chunk 405 appended.
# Chunk 406 appended.
# Chunk 407 appended.
# Chunk 408 appended.
# Chunk 409 appended.
# Chunk 410 appended.
# Chunk 411 appended.
# Chunk 412 appended.
# Chunk 413 appended.
# Chunk 414 appended.
# Chunk 415 appended.
# Chunk 416 appended.
# Chunk 417 appended.
# Chunk 418 appended.
# Chunk 419 appended.
# Chunk 420 appended.
# Chunk 421 appended.
# Chunk 422 appended.
# Chunk 423 appended.
# Chunk 424 appended.
# Chunk 425 appended.
# Chunk 426 appended.
# Chunk 427 appended.
# Chunk 428 appended.
# Chunk 429 appended.
# Chunk 430 appended.
# Chunk 431 appended.
# Chunk 432 appended.
# Chunk 433 appended.
# Chunk 434 appended.
# Chunk 435 appended.
# Chunk 436 appended.
# Chunk 437 appended.
# Chunk 438 appended.
# Chunk 439 appended.
# Chunk 440 appended.
# Chunk 441 appended.
# Chunk 442 appended.
# Chunk 443 appended.
# Chunk 444 appended.
# Chunk 445 appended.
# Chunk 446 appended.
# Chunk 447 appended.
# Chunk 448 appended.
# Chunk 449 appended.
# Chunk 450 appended.
# Chunk 451 appended.
# Chunk 452 appended.
# Chunk 453 appended.
# Chunk 454 appended.
# Chunk 455 appended.
# Chunk 456 appended.
# Chunk 457 appended.
# Chunk 458 appended.
# Chunk 459 appended.
# Chunk 460 appended.
# Chunk 461 appended.
# Chunk 462 appended.
# Chunk 463 appended.
# Chunk 464 appended.
# Chunk 465 appended.
# Chunk 466 appended.
# Chunk 467 appended.
# Chunk 468 appended.
# Chunk 469 appended.
# Chunk 470 appended.
# Chunk 471 appended.
# Chunk 472 appended.
# Chunk 473 appended.
# Chunk 474 appended.
# Chunk 475 appended.
# Chunk 476 appended.
# Chunk 477 appended.
# Chunk 478 appended.
# Chunk 479 appended.
# Chunk 480 appended.
# Chunk 481 appended.
# Chunk 482 appended.
# Chunk 483 appended.
# Chunk 484 appended.
# Chunk 485 appended.
# Chunk 486 appended.
# Chunk 487 appended.
# Chunk 488 appended.
# Chunk 489 appended.
# Chunk 490 appended.
# Chunk 491 appended.
# Chunk 492 appended.
# Chunk 493 appended.
# Chunk 494 appended.
# Chunk 495 appended.
# Chunk 496 appended.
# Chunk 497 appended.
# Chunk 498 appended.
# Chunk 499 appended.
# Chunk 500 appended.
# Chunk 501 appended.
# Chunk 502 appended.
# Chunk 503 appended.
# Chunk 504 appended.
# Chunk 505 appended.
# Chunk 506 appended.
# Chunk 507 appended.
# Chunk 508 appended.
# Chunk 509 appended.
# Chunk 510 appended.
# Chunk 511 appended.
# Chunk 512 appended.
# Chunk 513 appended.
# Chunk 514 appended.
# Chunk 515 appended.
# Chunk 516 appended.
# Chunk 517 appended.
# Chunk 518 appended.
# Chunk 519 appended.
# Chunk 520 appended.
# Chunk 521 appended.
# Chunk 522 appended.
# Chunk 523 appended.
# Chunk 524 appended.
# Chunk 525 appended.
# Chunk 526 appended.
# Chunk 527 appended.
# Chunk 528 appended.
# Chunk 529 appended.
# Chunk 530 appended.
# Chunk 531 appended.
# Chunk 532 appended.
# Chunk 533 appended.
# Chunk 534 appended.
# Chunk 535 appended.
# Chunk 536 appended.
# Chunk 537 appended.
# Chunk 538 appended.
# Chunk 539 appended.
# Chunk 540 appended.
# Chunk 541 appended.
# Chunk 542 appended.
# Chunk 543 appended.
# Chunk 544 appended.
# Chunk 545 appended.
# Chunk 546 appended.
# Chunk 547 appended.
# Chunk 548 appended.
# Chunk 549 appended.
# Chunk 550 appended.
# Chunk 551 appended.
# Chunk 552 appended.
# Chunk 553 appended.
# Chunk 554 appended.
# Chunk 555 appended.
# Chunk 556 appended.
# Chunk 557 appended.
# Chunk 558 appended.
# Chunk 559 appended.
# Chunk 560 appended.
# Chunk 561 appended.
# Chunk 562 appended.
# Chunk 563 appended.
# Chunk 564 appended.
# Chunk 565 appended.
# Chunk 566 appended.
# Chunk 567 appended.
# Chunk 568 appended.
# Chunk 569 appended.
# Chunk 570 appended.
# Chunk 571 appended.
# Chunk 572 appended.
# Chunk 573 appended.
# Chunk 574 appended.
# Chunk 575 appended.
# Chunk 576 appended.
# Chunk 577 appended.
# Chunk 578 appended.
# Chunk 579 appended.
# Chunk 580 appended.
# Chunk 581 appended.
# Chunk 582 appended.
# Chunk 583 appended.
# Chunk 584 appended.
# Chunk 585 appended.
# Chunk 586 appended.
# Chunk 587 appended.
# Chunk 588 appended.
# Chunk 589 appended.
# Chunk 590 appended.
# Chunk 591 appended.
# Chunk 592 appended.
# Chunk 593 appended.
# Chunk 594 appended.
# Chunk 595 appended.
# Chunk 596 appended.
# Chunk 597 appended.
# Chunk 598 appended.
# Chunk 599 appended.
# Chunk 600 appended.
# Chunk 601 appended.
# Chunk 602 appended.
# Chunk 603 appended.
# Chunk 604 appended.
# Chunk 605 appended.
# Chunk 606 appended.
# Chunk 607 appended.
# Chunk 608 appended.
# Chunk 609 appended.
# Chunk 610 appended.
# Chunk 611 appended.
# Chunk 612 appended.
# Chunk 613 appended.
# Chunk 614 appended.
# Chunk 615 appended.
# Chunk 616 appended.
# Chunk 617 appended.
# Chunk 618 appended.
# Chunk 619 appended.
# Chunk 620 appended.
# Chunk 621 appended.
# Chunk 622 appended.
# Chunk 623 appended.
# Chunk 624 appended.
# Chunk 625 appended.
# Chunk 626 appended.
# Chunk 627 appended.
# Chunk 628 appended.
# Chunk 629 appended.
# Chunk 630 appended.
# Chunk 631 appended.
# Chunk 632 appended.
# Chunk 633 appended.
# Chunk 634 appended.
# Chunk 635 appended.
# Chunk 636 appended.
# Chunk 637 appended.
# Chunk 638 appended.
# Chunk 639 appended.
# Chunk 640 appended.
# Chunk 641 appended.
# Chunk 642 appended.
# Chunk 643 appended.
# Chunk 644 appended.
# Chunk 645 appended.
# Chunk 646 appended.
# Chunk 647 appended.
# Chunk 648 appended.
# Chunk 649 appended.
# Chunk 650 appended.
# Chunk 651 appended.
# Chunk 652 appended.
# Chunk 653 appended.
# Chunk 654 appended.
# Chunk 655 appended.
# Chunk 656 appended.
# Chunk 657 appended.
# Chunk 658 appended.
# Chunk 659 appended.
# Chunk 660 appended.
# Chunk 661 appended.
# Chunk 662 appended.
# Chunk 663 appended.
# Chunk 664 appended.
# Chunk 665 appended.
# Chunk 666 appended.
# Chunk 667 appended.
# Chunk 668 appended.
# Chunk 669 appended.
# Chunk 670 appended.
# Chunk 671 appended.
# Chunk 672 appended.
# Chunk 673 appended.
# Chunk 674 appended.
# Chunk 675 appended.
# Chunk 676 appended.
# Chunk 677 appended.
# Chunk 678 appended.
# Chunk 679 appended.
# Chunk 680 appended.
# Chunk 681 appended.
# Chunk 682 appended.
# Chunk 683 appended.
# Chunk 684 appended.
# Chunk 685 appended.
# Chunk 686 appended.
# Chunk 687 appended.
# Chunk 688 appended.
# Chunk 689 appended.
# Chunk 690 appended.
# Chunk 691 appended.
# Chunk 692 appended.
# Chunk 693 appended.
# Chunk 694 appended.
# Chunk 695 appended.
# Chunk 696 appended.
# Chunk 697 appended.
# Chunk 698 appended.
# Chunk 699 appended.

# %% [markdown]
# Once the dataset is converted to parquet, we can load it using Dask for further processing.

# %%
df = dd.read_parquet(parquet_file)

# %% [markdown]
# ## Displaying Shape

# %% [markdown]
# Before performing any sampling, we will inspect the shape of the dataset. Initially, the dataset contains approximately 6.9 million rows and 9 columns.

# %%
print(f"Shape: ({len(df)}, {len(df.columns)})")
# Out:
# Shape: (6990280, 9)

# %% [markdown]
# ## Mapping Stars to Sentiments

# %% [markdown]
# We can map the star ratings into sentiments as follows:
#
# - **Negative**: Ratings between 1 and 3 stars (1 ≤ stars ≤ 2)
#
# - **Neutral**: Ratings equal to 3 stars (stars = 3)
#
# - **Positive**: Ratings between 4 and 5 stars (4 ≤ stars ≤ 5)

# %%
def map_sentiment(stars):
    return stars.map({1.0: "negative", 2.0: "negative", 3.0: "neutral", 4.0: "positive", 5.0: "positive"})

df["sentiment"] = df["stars"]. \
                    map_partitions(map_sentiment, meta=("sentiment", "category"))  # category is the datatype of resultant sentiment column

df.head(10)
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
# 5  JrIxlS1TzJ-iCu79ul40cQ  eUta8W_HdHMXPzLBBZhL1A  04UD14gamNjLY0IDYVhHJg
# 6  6AxgBCNX_PNTOxmbRSwcKQ  r3zeYsv1XFBRA4dJpL78cw  gmjsEdUsKpj9Xxu6pdjH0g
# 7  _ZeMknuYdlQcUqng_Im3yg  yfFzsLmaWF2d4Sr0UNbBgg  LHSTtnW3YHCeUkRDGyJOyw
# 8  ZKvDG2sBvHVdF5oBNUOpAQ  wSTuiTk-sKNdcFyprzZAjg  B5XSoSG3SfvQGtKEGQ1tSQ
# 9  pUycOfUwM8vqX7KjRRhUEA  59MxRhNVhU9MYndMkz0wtw  gebiRewfieSdtt17PTW6Zg
#
#    stars  useful  funny  cool  \
# 0      3       0      0     0
# 1      5       1      0     1
# 2      3       0      0     0
# 3      5       1      0     1
# 4      4       1      0     1
# 5      1       1      2     1
# 6      5       0      2     0
# 7      5       2      0     0
# 8      3       1      1     0
# 9      3       0      0     0
#
#                                                 text                date  \
# 0  If you decide to eat here, just be aware it is... 2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year... 2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm... 2014-02-05 20:30:30
# 3  Wow!  Yummy, different,  delicious.   Our favo... 2015-01-04 00:01:03
# 4  Cute interior and owner (?) gave us tour of up... 2017-01-14 20:54:15
# 5  I am a long term frequent customer of this est... 2015-09-23 23:10:31
# 6  Loved this tour! I grabbed a groupon and the p... 2015-01-03 23:21:18
# 7  Amazingly amazing wings and homemade bleu chee... 2015-08-07 02:29:16
# 8  This easter instead of going to Lopez Lake we ... 2016-03-30 22:46:33
# 9  Had a party of 6 here for hibachi. Our waitres... 2016-07-25 07:31:06
#
#   sentiment
# 0   neutral
# 1  positive
# 2   neutral
# 3  positive
# 4  positive
# 5  negative
# 6  positive
# 7  positive
# 8   neutral
# 9   neutral

# %% [markdown]
# ## Displaying Dataset

# %% [markdown]
# We display the dataset and its shape again to confirm data integrity and ensure that no corruption occured during conversion.

# %%
print(f"{len(df), len(df.columns)}")
df.head(10)
# Out:
# (6990280, 10)
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
# 5  JrIxlS1TzJ-iCu79ul40cQ  eUta8W_HdHMXPzLBBZhL1A  04UD14gamNjLY0IDYVhHJg
# 6  6AxgBCNX_PNTOxmbRSwcKQ  r3zeYsv1XFBRA4dJpL78cw  gmjsEdUsKpj9Xxu6pdjH0g
# 7  _ZeMknuYdlQcUqng_Im3yg  yfFzsLmaWF2d4Sr0UNbBgg  LHSTtnW3YHCeUkRDGyJOyw
# 8  ZKvDG2sBvHVdF5oBNUOpAQ  wSTuiTk-sKNdcFyprzZAjg  B5XSoSG3SfvQGtKEGQ1tSQ
# 9  pUycOfUwM8vqX7KjRRhUEA  59MxRhNVhU9MYndMkz0wtw  gebiRewfieSdtt17PTW6Zg
#
#    stars  useful  funny  cool  \
# 0      3       0      0     0
# 1      5       1      0     1
# 2      3       0      0     0
# 3      5       1      0     1
# 4      4       1      0     1
# 5      1       1      2     1
# 6      5       0      2     0
# 7      5       2      0     0
# 8      3       1      1     0
# 9      3       0      0     0
#
#                                                 text                date  \
# 0  If you decide to eat here, just be aware it is... 2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year... 2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm... 2014-02-05 20:30:30
# 3  Wow!  Yummy, different,  delicious.   Our favo... 2015-01-04 00:01:03
# 4  Cute interior and owner (?) gave us tour of up... 2017-01-14 20:54:15
# 5  I am a long term frequent customer of this est... 2015-09-23 23:10:31
# 6  Loved this tour! I grabbed a groupon and the p... 2015-01-03 23:21:18
# 7  Amazingly amazing wings and homemade bleu chee... 2015-08-07 02:29:16
# 8  This easter instead of going to Lopez Lake we ... 2016-03-30 22:46:33
# 9  Had a party of 6 here for hibachi. Our waitres... 2016-07-25 07:31:06
#
#   sentiment
# 0   neutral
# 1  positive
# 2   neutral
# 3  positive
# 4  positive
# 5  negative
# 6  positive
# 7  positive
# 8   neutral
# 9   neutral

# %% [markdown]
# ## Sampling Dataset

# %% [markdown]
# Since our target is to sample 1.5 million rows, we need to ensure randomness along with class balance across all three sentiments (positive, negative, neutral). Thus, we need 500,000 rows for each sentiment.

# %%
target_per_class = 500_000
seed = 42                                                           # Ensures randomness but reproducibility
sentiment_counts = df['sentiment'].value_counts().compute()         # Caclulates count for each sentiment in entire dataset

# %% [markdown]
# Next, we divide the number of rows per sentiment class by the total length of the dataset. And then sample approximately 500,000 rows per class. For each sentiment, we sample the 500,000 rows and then append them to create a `balanced_df`.

# %%
sampled_dfs = []

for sentiment in ["negative", "neutral", "positive"]:
    sentiment_df = df[df.sentiment == sentiment]

    frac = (target_per_class + 10) / len(sentiment_df)                          # The + 10 is set as an offset, since the frac variable
                                                                                # works with floating point calculations

    sampled_df = sentiment_df.sample(frac=frac, random_state=seed).compute()

    sampled_df = sampled_df.sample(n=target_per_class, random_state=seed)

    sampled_dfs.append(sampled_df)

balanced_df = dd.from_pandas(pd.concat(sampled_dfs), npartitions=df.npartitions)


print(balanced_df['sentiment'].value_counts().compute())
# Out:
# sentiment
# positive    500000
# neutral     500000
# negative    500000
# Name: count, dtype: int64[pyarrow]

# %% [markdown]
# ## Saving the Dataset

# %% [markdown]
# Lastly, we save the `balanced_df` to parquet for preprocessing.

# %%
# engine='pyarrow' that is part of Apache Arrow, used to read parquet files.

balanced_df.to_parquet("yelp_reviews_sampled.parquet", engine="pyarrow", write_index=False)
